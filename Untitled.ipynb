# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
file_path = r'C:\Users\LENOVO\OneDrive\Documents\GitHub\Dailytrue.csv'
data=pd.read_csv(file_path)

# %%
data.head()
# Out:
#     Tanggal   Per Hari   Growth  Unnamed: 3
# 0  11-Mar-23          2       2         NaN
# 1  12-Mar-23          0       2         NaN
# 2  13-Mar-23          3       5         NaN
# 3  14-Mar-23          1       6         NaN
# 4  15-Mar-23          2       8         NaN

# %%
data=pd.read_csv(file_path, index_col=0)
data.head()
# Out:
#            Per Hari   Growth  Unnamed: 3
# Tanggal
# 11-Mar-23          2       2         NaN
# 12-Mar-23          0       2         NaN
# 13-Mar-23          3       5         NaN
# 14-Mar-23          1       6         NaN
# 15-Mar-23          2       8         NaN

# %%
data.shape
# Out:
# (61, 3)

# %%
data.describe()
# Out:
#        Per Hari      Growth  Unnamed: 3
# count  61.000000  61.000000         0.0
# mean    0.836066  32.295082         NaN
# std     1.098185  16.133138         NaN
# min     0.000000   2.000000         NaN
# 25%     0.000000  16.000000         NaN
# 50%     0.000000  38.000000         NaN
# 75%     1.000000  46.000000         NaN
# max     5.000000  51.000000         NaN

# %% [markdown]
# ## Slicing

# %%
growth= data['Growth']
growth
# Out:
# Tanggal
# 11-Mar-23     2
# 12-Mar-23     2
# 13-Mar-23     5
# 14-Mar-23     6
# 15-Mar-23     8
#              ..
# 6-May-23     50
# 7-May-23     50
# 8-May-23     50
# 9-May-23     51
# 10-May-23    51
# Name: Growth, Length: 61, dtype: int64

# %%
growth.shape
# Out:
# (61,)

# %%
# %matplotlib notebook

# %%
plt.plot(growth,label='Growth')
plt.xlabel('Tanggal')
plt.ylabel('Growth')
plt.title('Kenaikan daily',fontsize=10)
plt.grid()
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="954">
